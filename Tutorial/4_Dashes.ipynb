# %%
import sys
import os

import pandas as pd
# import polars as pl

from matplotlib import pyplot as plt
# %matplotlib inline  

sys.path.append('/Users/mihail/Documents/repos/analyzer')
print(sys.version)

from analyzer.dashs import VarStatDash, ConcentrationDash
# Out:
# 3.13.2 (main, Feb  4 2025, 14:51:09) [Clang 16.0.0 (clang-1600.0.26.6)]

# %% [markdown]
# # Подготовка
# Загрузим датафрейм, на котором продемонстрируем функционал.

# %%
df = pd.read_csv('/Users/mihail/Documents/repos/analyzer/tests/Titanic-Dataset.csv')
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# # Функционал

# %% [markdown]
# ## VarStatDash
# Дашборд для плоского анализа переменных.

# %%
# ?VarStatDash
# Out:
# Init signature:
# VarStatDash(
#     df: ~DataFrame,
#     targets_names: List[str] = None,
#     bad_cols_start: int = 20,
# )
# Docstring:
# Дашборд для плоского анализа переменных.
# Args:
#     df:                         Исследуемый датафрейм.
#     targets_names:                    Список таргетов, можно не задавать, в этом случае будут определены бинарные колонки
#                                 в датафрейме и подставлены как возможный таргет.
#     bad_cols_start:             Не будет отображать колонки, число категорий в которых превысит заданное значение.
#                                 Отметит их крестиком.
#
# Применение:
# 1. Подали любой датафрейм на вход, бинаризавоать колонки не нужно, это будет происходить под капотом.
# 2. Выбирая значения в виджетах X1/X2/Target вы сможете отобразить статистики в виде графика и таблицы.
# 3. Список переменных в виджетах X1 и X2 отсортированы по алфавиту. Но если нажать "Сортировать (IV)" то
# ...

# %%
VarStatDash(df)

# %% [markdown]
# __Пример изображений дашборда:__

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## ConcentrationDash
# Дашборд для поиска концентрации и деконцентрации Target-a в данных.

# %%
# ?ConcentrationDash
# Out:
# Init signature:
# ConcentrationDash(
#     df: ~DataFrame,
#     targets_names: List[str],
#     combo_min: int = 1,
#     combo_max: int = 2,
#     min_bin: float = 20.0,
#     bad_cols_start: int = 30,
#     max_cached_reports=3,
# )
# Docstring:
# Дашборд для поиска концентрации и деконцентрации Target-a в данных.
#
# Args:
#     df:                         Исследуемый датафрейм.
#     targets_names:              Список таргетов, можно не задавать, в этом случае будут определены бинарные колонки
#                                 в датафрейме и подставлены как возможный таргет.
#     combo_min:                  Минимальное количество переменных, участвующих в комбинировании
#     combo_max:                  Максимальное количество переменных, участвующих в комбинировании
#     min_bin:                    Минимальный размер бакета для бинаризации.
#     bad_cols_start:             Колонки имеющие, число категорий превышающее заданное значение,
# ...

# %%
ConcentrationDash(df, combo_max = 4, targets_names=['Survived'])
# Out:
# ...
# Output(layout=Layout(align_items='center', justify_content='center', width='100%'))

# %% [markdown]
# __Пример отображения дашборда:__

# %% [markdown]
# <img src="data:image/png;base64,..." />
